# %% [markdown]
# #Tourism hierarachy
# https://github.com/erykml/medium_articles/blob/master/data/tourism.csv
#
#
#
# The data set contains the quarterly number of trips to Australia between 1998 and 2016

# %% [markdown]
# **url**  https://towardsdatascience.com/introduction-to-hierarchical-time-series-forecasting-part-ii-e73dfd3de86b
#
# **date_of_publish** Mar 14 2021
#
#
# **python package_name** scikit-hts pmdarima
#
# github_page

# %%
# !pip install pmdarima
# !pip install scikit-hts==0.5.3
# Out:
# Collecting pmdarima
#   Downloading https://files.pythonhosted.org/packages/f4/c2/2a94bce6bba1deac3c0b16dbb14f28de0b9035e3211919cae8448455aa65/pmdarima-1.8.2-cp37-cp37m-manylinux1_x86_64.whl (1.5MB)
#      |████████████████████████████████| 1.5MB 9.3MB/s
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.0.1)
# Collecting statsmodels!=0.12.0,>=0.11
#   Downloading https://files.pythonhosted.org/packages/da/69/8eef30a6237c54f3c0b524140e2975f4b1eea3489b45eb3339574fc8acee/statsmodels-0.12.2-cp37-cp37m-manylinux1_x86_64.whl (9.5MB)
#      |████████████████████████████████| 9.5MB 33.8MB/s
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (0.22.2.post1)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.4.1)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.1.5)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.24.3)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (56.1.0)
# Requirement already satisfied: numpy~=1.19.0 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.19.5)
# Requirement already satisfied: Cython!=0.29.18,>=0.29 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (0.29.23)
# Requirement already satisfied: patsy>=0.5 in /usr/local/lib/python3.7/dist-packages (from statsmodels!=0.12.0,>=0.11->pmdarima) (0.5.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->pmdarima) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->pmdarima) (2.8.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from patsy>=0.5->statsmodels!=0.12.0,>=0.11->pmdarima) (1.15.0)
# Installing collected packages: statsmodels, pmdarima
#   Found existing installation: statsmodels 0.10.2
#     Uninstalling statsmodels-0.10.2:
#       Successfully uninstalled statsmodels-0.10.2
# Successfully installed pmdarima-1.8.2 statsmodels-0.12.2
# Collecting scikit-hts==0.5.3
#   Downloading https://files.pythonhosted.org/packages/ab/ef/dcd0e74836cce685fb2540f9e5e19c244f90f519f2133cf7b3dba630e587/scikit_hts-0.5.3-py2.py3-none-any.whl
# Requirement already satisfied: pandas>=0.25.3 in /usr/local/lib/python3.7/dist-packages (from scikit-hts==0.5.3) (1.1.5)
# Requirement already satisfied: numpy>=1.17.4 in /usr/local/lib/python3.7/dist-packages (from scikit-hts==0.5.3) (1.19.5)
# Collecting tqdm>=4.43
#   Downloading https://files.pythonhosted.org/packages/42/d7/f357d98e9b50346bcb6095fe3ad205d8db3174eb5edb03edfe7c4099576d/tqdm-4.61.0-py2.py3-none-any.whl (75kB)
#      |████████████████████████████████| 81kB 6.8MB/s
# Requirement already satisfied: statsmodels>=0.10.2 in /usr/local/lib/python3.7/dist-packages (from scikit-hts==0.5.3) (0.12.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.7/dist-packages (from scikit-hts==0.5.3) (1.4.1)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.7/dist-packages (from scikit-hts==0.5.3) (0.22.2.post1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.3->scikit-hts==0.5.3) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.3->scikit-hts==0.5.3) (2018.9)
# Requirement already satisfied: patsy>=0.5 in /usr/local/lib/python3.7/dist-packages (from statsmodels>=0.10.2->scikit-hts==0.5.3) (0.5.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.21.3->scikit-hts==0.5.3) (1.0.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.25.3->scikit-hts==0.5.3) (1.15.0)
# Installing collected packages: tqdm, scikit-hts
#   Found existing installation: tqdm 4.41.1
#     Uninstalling tqdm-4.41.1:
#       Successfully uninstalled tqdm-4.41.1
# Successfully installed scikit-hts-0.5.3 tqdm-4.61.0

# %%
import pandas as pd
import numpy as np
import hts

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.simplefilter("ignore")

# settings
plt.style.use('seaborn')
plt.rcParams["figure.figsize"] = (16, 8)

# %%
# !ls -al
# !rm 'tourism.csv'
# Out:
# total 16
# drwxr-xr-x 1 root root 4096 May  6 13:44 .
# drwxr-xr-x 1 root root 4096 May 26 20:40 ..
# drwxr-xr-x 4 root root 4096 May  6 13:43 .config
# drwxr-xr-x 1 root root 4096 May  6 13:44 sample_data
# rm: cannot remove 'tourism.csv': No such file or directory

# %%
# %config InlineBackend.figure_format = 'retina'

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-aaaca94c-421a-4556-94d1-d5d217a73c0a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-aaaca94c-421a-4556-94d1-d5d217a73c0a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving tourism.csv to tourism.csv

# %%
import io
# load the data 
df = pd.read_csv(io.BytesIO(uploaded['tourism.csv'])) \
       .drop(columns=["Unnamed: 0"])
# df = pd.read_csv('tourism.csv') \
#        .drop(columns=["Unnamed: 0"])

# %%
# lowercase the column names
df.columns = [col_name.lower() for col_name in df.columns]

# sum the trips over purpose
df = df.groupby(["quarter", "region", "state"])["trips"] \
       .sum() \
       .reset_index(drop=False)

# cleanup region name 
df["region"] = df["region"].apply(lambda x: x.replace(" ", "_").replace("'", ""))

# map the full state names to abbreviations
mapping_dict = {
    "New South Wales": "NSW",
    "Northern Territory": "NT",
    "Queensland": "QLD",
    "South Australia": "SA",
    "Victoria": "VIC",
    "Western Australia": "WA",
    "ACT": "ACT",
}

df["state"] = df["state"].map(mapping_dict)

# create the bottom level id
df["state_region"] = df.apply(lambda x: f"{x['state']}_{x['region']}", axis=1)

df.head()
# Out:
#       quarter  ...                  state_region
# 0  1998-01-01  ...                   SA_Adelaide
# 1  1998-01-01  ...             SA_Adelaide_Hills
# 2  1998-01-01  ...              NT_Alice_Springs
# 3  1998-01-01  ...     WA_Australias_Coral_Coast
# 4  1998-01-01  ...  WA_Australias_Golden_Outback
#
# [5 rows x 5 columns]

# %%
df.groupby("state")["region"].apply(set).to_frame()
# Out:
#                                                   region
# state
# ACT                                           {Canberra}
# NSW    {The_Murray, Blue_Mountains, Central_NSW, Snow...
# NT     {Wilderness_West, Tasmania, Alice_Springs, Kat...
# QLD    {Mackay, Outback, Darling_Downs, Central_Queen...
# SA     {Yorke_Peninsula, Riverland, Clare_Valley, Ade...
# VIC    {Murray_East, Mallee, Central_Highlands, Geelo...
# WA     {Australias_North_West, Australias_South_West,...

# %%
# create the bottom level df
df_bottom_level = df.pivot(index="quarter", columns="state_region", values="trips")

# create the middle level df
df_middle_level = df.groupby(["quarter", "state"]) \
                    .sum() \
                    .reset_index(drop=False) \
                    .pivot(index="quarter", columns="state", values="trips")

# create the total level df
df_total = df.groupby("quarter")["trips"] \
             .sum() \
             .to_frame() \
             .rename(columns={"trips": "total"})

# join the DataFrames
hierarchy_df = df_bottom_level.join(df_middle_level) \
                              .join(df_total)
hierarchy_df.index = pd.to_datetime(hierarchy_df.index)
hierarchy_df = hierarchy_df.resample("QS") \
                           .sum()

print(f"Number of time series at the bottom level: {df_bottom_level.shape[1]}")
print(f"Number of time series at the middle level: {df_middle_level.shape[1]}")

hierarchy_df.head()
# Out:
# Number of time series at the bottom level: 77
# Number of time series at the middle level: 7
#             ACT_Canberra  NSW_Blue_Mountains  ...           WA         total
# quarter                                       ...
# 1998-01-01    551.001921          195.543180  ...  1641.089495  23932.544141
# 1998-04-01    416.025623          200.408671  ...  1576.326534  20856.726540
# 1998-07-01    436.029011          253.359689  ...  1588.293692  20222.802189
# 1998-10-01    449.798445          245.573846  ...  1839.716990  21342.960517
# 1999-01-01    378.572817          290.484124  ...  1835.687573  22801.711403
#
# [5 rows x 85 columns]

# %%
states = df["state"].unique()
regions = df["state_region"].unique()

total = {'total': list(states)}
state = {k: [v for v in regions if v.startswith(k)] for k in states}
hierarchy = {**total, **state}

#hierarchy

# %%
from hts.hierarchy import HierarchyTree

ht = HierarchyTree.from_nodes(nodes=hierarchy, df=hierarchy_df)
ht
# Out:
# - total
#    |- SA
#    |  |- SA_Adelaide
#    |  |- SA_Adelaide_Hills
#    |  |- SA_Barossa
#    |  |- SA_Clare_Valley
#    |  |- SA_Eyre_Peninsula
#    |  |- SA_Fleurieu_Peninsula
#    |  |- SA_Flinders_Ranges_and_Outback
#    |  |- SA_Kangaroo_Island
#    |  |- SA_Limestone_Coast
#    |  |- SA_Murraylands
#    |  |- SA_Riverland
#    |  - SA_Yorke_Peninsula
#    |- NT
#    |  |- NT_Alice_Springs
#    |  |- NT_Barkly
#    |  |- NT_Darwin
#    |  |- NT_East_Coast
#    |  |- NT_Hobart_and_the_South
#    |  |- NT_Kakadu_Arnhem
#    |  |- NT_Katherine_Daly
#    |  |- NT_Lasseter
#    |  |- NT_Launceston,_Tamar_and_the_North
#    |  |- NT_MacDonnell
#    |  |- NT_North_West
#    |  |- NT_Tasmania
#    |  - NT_Wilderness_West
#    |- WA
#    |  |- WA_Australias_Coral_Coast
#    |  |- WA_Australias_Golden_Outback
#    |  |- WA_Australias_North_West
#    |  |- WA_Australias_South_West
#    |  - WA_Experience_Perth
#    |- VIC
#    |  |- VIC_Ballarat
#    |  |- VIC_Bendigo_Loddon
#    |  |- VIC_Central_Highlands
#    |  |- VIC_Central_Murray
#    |  |- VIC_Geelong
#    |  |- VIC_Gippsland
#    |  |- VIC_Goulburn
#    |  |- VIC_High_Country
#    |  |- VIC_Lakes
#    |  |- VIC_Macedon
#    |  |- VIC_Mallee
#    |  |- VIC_Melbourne
#    |  |- VIC_Melbourne_East
#    |  |- VIC_Murray_East
#    |  |- VIC_Peninsula
#    |  |- VIC_Phillip_Island
#    |  |- VIC_Spa_Country
#    |  |- VIC_Upper_Yarra
#    |  |- VIC_Western
#    |  |- VIC_Western_Grampians
#    |  - VIC_Wimmera
#    |- NSW
#    |  |- NSW_Blue_Mountains
#    |  |- NSW_Capital_Country
#    |  |- NSW_Central_Coast
#    |  |- NSW_Central_NSW
#    |  |- NSW_Hunter
#    |  |- NSW_New_England_North_West
#    |  |- NSW_North_Coast_NSW
#    |  |- NSW_Outback_NSW
#    |  |- NSW_Riverina
#    |  |- NSW_Snowy_Mountains
#    |  |- NSW_South_Coast
#    |  |- NSW_Sydney
#    |  - NSW_The_Murray
#    |- QLD
#    |  |- QLD_Brisbane
#    |  |- QLD_Bundaberg
#    |  |- QLD_Central_Queensland
#    |  |- QLD_Darling_Downs
#    |  |- QLD_Fraser_Coast
#    |  |- QLD_Gold_Coast
#    |  |- QLD_Mackay
#    |  |- QLD_Northern
#    |  |- QLD_Outback
#    |  |- QLD_Sunshine_Coast
#    |  |- QLD_Tropical_North_Queensland
#    |  - QLD_Whitsundays
#    - ACT
#       - ACT_Canberra

# %% [markdown]
# #Visualizing the data

# %%
hierarchy_df["total"].plot(title="Trips - total level");

# %%
ax = hierarchy_df[hierarchy['total']].plot(title="Trips - state level")
ax.legend(bbox_to_anchor=(1.0, 1.0));

# %%
ax = hierarchy_df[hierarchy['WA']].plot(title="Trips - regions of Western Australia")
ax.legend(bbox_to_anchor=(1.0, 1.0));

# %% [markdown]
# #Hierarchical time series forecasting

# %%
def plot_results(pred_df, source_df, cols_to_plot):
    """
    Helper function used for displaying the predictions vs. actuals for the indicated columns
    """
    
    if type(cols_to_plot) == str:
        cols_to_plot = list(cols_to_plot)
        
    for col in cols_to_plot:
        fig, ax = plt.subplots()
        pred_df[col].plot(ax=ax, label="Predicted")
        source_df[col].plot(ax=ax, label="Observed")
        
        ax.legend()
        ax.set_title(col)
        ax.set_xlabel("Date")
        ax.set_ylabel("Trips");

# %% [markdown]
# #  prophet-APH

# %%
model_APH_prophet = hts.HTSRegressor(model='prophet', revision_method='AHP', n_jobs=0)
model_APH_prophet = model_APH_prophet.fit(hierarchy_df, hierarchy)
pred_APH_prophet = model_APH_prophet.predict(steps_ahead=4)
# Out:
# Fitting models:   0%|          | 0/85 [00:00<?, ?it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:   1%|          | 1/85 [00:01<01:37,  1.17s/it]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:   2%|▏         | 2/85 [00:02<01:28,  1.06s/it]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:   4%|▎         | 3/85 [00:03<01:31,  1.11s/it]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:   5%|▍         | 4/85 [00:04<01:27,  1.08s/it]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:   6%|▌         | 5/85 [00:05<01:21,  1.02s/it]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:   7%|▋         | 6/85 [00:06<01:21,  1.03s/it]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:   8%|▊         | 7/85 [00:07<01:20,  1.03s/it]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:   9%|▉         | 8/85 [00:08<01:10,  1.10it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  11%|█         | 9/85 [00:08<01:03,  1.20it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  12%|█▏        | 10/85 [00:09<00:54,  1.39it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  13%|█▎        | 11/85 [00:09<00:51,  1.44it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  14%|█▍        | 12/85 [00:10<00:48,  1.51it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  15%|█▌        | 13/85 [00:10<00:45,  1.58it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  16%|█▋        | 14/85 [00:11<00:47,  1.50it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  18%|█▊        | 15/85 [00:12<00:45,  1.52it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  19%|█▉        | 16/85 [00:12<00:44,  1.56it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  20%|██        | 17/85 [00:13<00:45,  1.49it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  21%|██        | 18/85 [00:14<00:46,  1.44it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  22%|██▏       | 19/85 [00:15<00:47,  1.38it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  24%|██▎       | 20/85 [00:15<00:47,  1.36it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  25%|██▍       | 21/85 [00:16<00:43,  1.46it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  26%|██▌       | 22/85 [00:17<00:42,  1.48it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  27%|██▋       | 23/85 [00:17<00:43,  1.43it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  28%|██▊       | 24/85 [00:18<00:42,  1.45it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  29%|██▉       | 25/85 [00:19<00:41,  1.45it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  31%|███       | 26/85 [00:19<00:40,  1.45it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  32%|███▏      | 27/85 [00:20<00:37,  1.57it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  33%|███▎      | 28/85 [00:21<00:37,  1.53it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  34%|███▍      | 29/85 [00:21<00:35,  1.57it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  35%|███▌      | 30/85 [00:22<00:31,  1.73it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  36%|███▋      | 31/85 [00:22<00:31,  1.72it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  38%|███▊      | 32/85 [00:23<00:31,  1.68it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  39%|███▉      | 33/85 [00:23<00:29,  1.75it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  40%|████      | 34/85 [00:24<00:35,  1.44it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  41%|████      | 35/85 [00:25<00:30,  1.63it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  42%|████▏     | 36/85 [00:26<00:37,  1.32it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  44%|████▎     | 37/85 [00:27<00:37,  1.28it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  45%|████▍     | 38/85 [00:28<00:39,  1.18it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  46%|████▌     | 39/85 [00:29<00:37,  1.21it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  47%|████▋     | 40/85 [00:30<00:39,  1.15it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  48%|████▊     | 41/85 [00:30<00:35,  1.23it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  49%|████▉     | 42/85 [00:31<00:37,  1.15it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  51%|█████     | 43/85 [00:32<00:32,  1.27it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  52%|█████▏    | 44/85 [00:33<00:33,  1.24it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  53%|█████▎    | 45/85 [00:34<00:33,  1.19it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  54%|█████▍    | 46/85 [00:34<00:29,  1.32it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  55%|█████▌    | 47/85 [00:35<00:25,  1.46it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  56%|█████▋    | 48/85 [00:35<00:25,  1.47it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  58%|█████▊    | 49/85 [00:36<00:25,  1.44it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  59%|█████▉    | 50/85 [00:37<00:27,  1.28it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  60%|██████    | 51/85 [00:38<00:26,  1.29it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  61%|██████    | 52/85 [00:39<00:30,  1.08it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  62%|██████▏   | 53/85 [00:40<00:30,  1.04it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  64%|██████▎   | 54/85 [00:41<00:29,  1.04it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  65%|██████▍   | 55/85 [00:42<00:26,  1.13it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  66%|██████▌   | 56/85 [00:42<00:23,  1.22it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  67%|██████▋   | 57/85 [00:44<00:25,  1.09it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  68%|██████▊   | 58/85 [00:44<00:24,  1.12it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  69%|██████▉   | 59/85 [00:45<00:22,  1.16it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  71%|███████   | 60/85 [00:46<00:20,  1.24it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  72%|███████▏  | 61/85 [00:47<00:19,  1.22it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  73%|███████▎  | 62/85 [00:47<00:16,  1.43it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  74%|███████▍  | 63/85 [00:48<00:16,  1.33it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  75%|███████▌  | 64/85 [00:49<00:15,  1.35it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  76%|███████▋  | 65/85 [00:50<00:16,  1.20it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  78%|███████▊  | 66/85 [00:51<00:16,  1.16it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  79%|███████▉  | 67/85 [00:52<00:15,  1.13it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  80%|████████  | 68/85 [00:53<00:15,  1.09it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  81%|████████  | 69/85 [00:54<00:16,  1.02s/it]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  82%|████████▏ | 70/85 [00:55<00:14,  1.01it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  84%|████████▎ | 71/85 [00:56<00:12,  1.12it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  85%|████████▍ | 72/85 [00:56<00:11,  1.17it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  86%|████████▌ | 73/85 [00:57<00:10,  1.16it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  87%|████████▋ | 74/85 [00:58<00:08,  1.29it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  88%|████████▊ | 75/85 [00:58<00:07,  1.39it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  89%|████████▉ | 76/85 [00:59<00:07,  1.25it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  91%|█████████ | 77/85 [01:00<00:06,  1.32it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  92%|█████████▏| 78/85 [01:01<00:06,  1.13it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  93%|█████████▎| 79/85 [01:02<00:04,  1.21it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  94%|█████████▍| 80/85 [01:02<00:03,  1.32it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  95%|█████████▌| 81/85 [01:04<00:03,  1.11it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  96%|█████████▋| 82/85 [01:05<00:02,  1.10it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  98%|█████████▊| 83/85 [01:06<00:01,  1.07it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  99%|█████████▉| 84/85 [01:07<00:00,  1.05it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models: 100%|██████████| 85/85 [01:07<00:00,  1.25it/s]
# Fitting models: 100%|██████████| 85/85 [02:21<00:00,  1.66s/it]
# INFO:hts.core.regressor:Reconciling forecasts using <hts.revision.RevisionMethod object at 0x7f54a4b62a50>

# %%
from sklearn.metrics import mean_squared_error
import numpy as np

from statsmodels.tools.eval_measures import rmse
arr=np.array(pred_APH_prophet.iloc[0,:])
arr1=np.array(hierarchy_df['total'])
print('RMSE',rmse(arr[:len(arr1)],arr1))

plot_results(pred_APH_prophet, hierarchy_df, cols_to_plot=['total'])
# Out:
# RMSE 21106.413095719356

# %%
plot_results(pred_APH_prophet, hierarchy_df, cols_to_plot=['SA'])
arr=np.array(pred_APH_prophet['SA'])
arr1=np.array(hierarchy_df['SA'])
print('RMSE',rmse(arr[:len(arr1)],arr1))
# Out:
# RMSE 109.8899564781419

# %%
plot_results(pred_APH_prophet, hierarchy_df, cols_to_plot=['SA_Adelaide_Hills'])
arr=np.array(pred_APH_prophet['SA_Adelaide_Hills'])
arr1=np.array(hierarchy_df['SA_Adelaide_Hills'])
print('RMSE',rmse(arr[:len(arr1)],arr1))
# Out:
# RMSE 13.566969421972264
