# %% [markdown]
# #Tourism hierarachy
# https://github.com/erykml/medium_articles/blob/master/data/tourism.csv
#
#
#
# The data set contains the quarterly number of trips to Australia between 1998 and 2016

# %% [markdown]
# **url**  https://towardsdatascience.com/introduction-to-hierarchical-time-series-forecasting-part-ii-e73dfd3de86b
#
# **date_of_publish** Mar 14 2021
#
#
# **python package_name** scikit-hts pmdarima
#
# github_page

# %%
# !pip install pmdarima
# !pip install scikit-hts==0.5.3
# Out:
# Collecting pmdarima
#   Downloading https://files.pythonhosted.org/packages/f4/c2/2a94bce6bba1deac3c0b16dbb14f28de0b9035e3211919cae8448455aa65/pmdarima-1.8.2-cp37-cp37m-manylinux1_x86_64.whl (1.5MB)
#      |████████████████████████████████| 1.5MB 28.7MB/s
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.4.1)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.1.5)
# Requirement already satisfied: numpy~=1.19.0 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.19.5)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.24.3)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (56.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.0.1)
# Collecting statsmodels!=0.12.0,>=0.11
#   Downloading https://files.pythonhosted.org/packages/da/69/8eef30a6237c54f3c0b524140e2975f4b1eea3489b45eb3339574fc8acee/statsmodels-0.12.2-cp37-cp37m-manylinux1_x86_64.whl (9.5MB)
#      |████████████████████████████████| 9.5MB 51.3MB/s
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (0.22.2.post1)
# Requirement already satisfied: Cython!=0.29.18,>=0.29 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (0.29.23)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->pmdarima) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->pmdarima) (2.8.1)
# Requirement already satisfied: patsy>=0.5 in /usr/local/lib/python3.7/dist-packages (from statsmodels!=0.12.0,>=0.11->pmdarima) (0.5.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.19->pmdarima) (1.15.0)
# Installing collected packages: statsmodels, pmdarima
#   Found existing installation: statsmodels 0.10.2
#     Uninstalling statsmodels-0.10.2:
#       Successfully uninstalled statsmodels-0.10.2
# Successfully installed pmdarima-1.8.2 statsmodels-0.12.2
# Collecting scikit-hts==0.5.3
#   Downloading https://files.pythonhosted.org/packages/ab/ef/dcd0e74836cce685fb2540f9e5e19c244f90f519f2133cf7b3dba630e587/scikit_hts-0.5.3-py2.py3-none-any.whl
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.7/dist-packages (from scikit-hts==0.5.3) (1.4.1)
# Requirement already satisfied: pandas>=0.25.3 in /usr/local/lib/python3.7/dist-packages (from scikit-hts==0.5.3) (1.1.5)
# Requirement already satisfied: statsmodels>=0.10.2 in /usr/local/lib/python3.7/dist-packages (from scikit-hts==0.5.3) (0.12.2)
# Collecting tqdm>=4.43
#   Downloading https://files.pythonhosted.org/packages/42/d7/f357d98e9b50346bcb6095fe3ad205d8db3174eb5edb03edfe7c4099576d/tqdm-4.61.0-py2.py3-none-any.whl (75kB)
#      |████████████████████████████████| 81kB 12.5MB/s
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.7/dist-packages (from scikit-hts==0.5.3) (0.22.2.post1)
# Requirement already satisfied: numpy>=1.17.4 in /usr/local/lib/python3.7/dist-packages (from scikit-hts==0.5.3) (1.19.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.3->scikit-hts==0.5.3) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.3->scikit-hts==0.5.3) (2.8.1)
# Requirement already satisfied: patsy>=0.5 in /usr/local/lib/python3.7/dist-packages (from statsmodels>=0.10.2->scikit-hts==0.5.3) (0.5.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.21.3->scikit-hts==0.5.3) (1.0.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.25.3->scikit-hts==0.5.3) (1.15.0)
# Installing collected packages: tqdm, scikit-hts
#   Found existing installation: tqdm 4.41.1
#     Uninstalling tqdm-4.41.1:
#       Successfully uninstalled tqdm-4.41.1
# Successfully installed scikit-hts-0.5.3 tqdm-4.61.0

# %%
import pandas as pd
import numpy as np
import hts

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.simplefilter("ignore")

# settings
plt.style.use('seaborn')
plt.rcParams["figure.figsize"] = (16, 8)

# %%
# !ls -al
# !rm 'tourism.csv'
# Out:
# total 16
# drwxr-xr-x 1 root root 4096 May  6 13:44 .
# drwxr-xr-x 1 root root 4096 May 26 19:46 ..
# drwxr-xr-x 4 root root 4096 May  6 13:43 .config
# drwxr-xr-x 1 root root 4096 May  6 13:44 sample_data
# rm: cannot remove 'tourism.csv': No such file or directory

# %%
# %config InlineBackend.figure_format = 'retina'

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c6d2d23c-f3e0-45b9-8997-d74e4896f3e8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c6d2d23c-f3e0-45b9-8997-d74e4896f3e8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving tourism.csv to tourism.csv

# %%
import io
# load the data 
df = pd.read_csv(io.BytesIO(uploaded['tourism.csv'])) \
       .drop(columns=["Unnamed: 0"])
# df = pd.read_csv('tourism.csv') \
#        .drop(columns=["Unnamed: 0"])

# %%
# lowercase the column names
df.columns = [col_name.lower() for col_name in df.columns]

# sum the trips over purpose
df = df.groupby(["quarter", "region", "state"])["trips"] \
       .sum() \
       .reset_index(drop=False)

# cleanup region name 
df["region"] = df["region"].apply(lambda x: x.replace(" ", "_").replace("'", ""))

# map the full state names to abbreviations
mapping_dict = {
    "New South Wales": "NSW",
    "Northern Territory": "NT",
    "Queensland": "QLD",
    "South Australia": "SA",
    "Victoria": "VIC",
    "Western Australia": "WA",
    "ACT": "ACT",
}

df["state"] = df["state"].map(mapping_dict)

# create the bottom level id
df["state_region"] = df.apply(lambda x: f"{x['state']}_{x['region']}", axis=1)

df.head()
# Out:
#       quarter  ...                  state_region
# 0  1998-01-01  ...                   SA_Adelaide
# 1  1998-01-01  ...             SA_Adelaide_Hills
# 2  1998-01-01  ...              NT_Alice_Springs
# 3  1998-01-01  ...     WA_Australias_Coral_Coast
# 4  1998-01-01  ...  WA_Australias_Golden_Outback
#
# [5 rows x 5 columns]

# %%
df.groupby("state")["region"].apply(set).to_frame()
# Out:
#                                                   region
# state
# ACT                                           {Canberra}
# NSW    {Sydney, Hunter, Central_Coast, Central_NSW, S...
# NT     {Kakadu_Arnhem, Barkly, Alice_Springs, Hobart_...
# QLD    {Tropical_North_Queensland, Outback, Whitsunda...
# SA     {Kangaroo_Island, Limestone_Coast, Riverland, ...
# VIC    {Lakes, Western, Macedon, Geelong, Wimmera, Pe...
# WA     {Australias_Coral_Coast, Australias_Golden_Out...

# %%
# create the bottom level df
df_bottom_level = df.pivot(index="quarter", columns="state_region", values="trips")

# create the middle level df
df_middle_level = df.groupby(["quarter", "state"]) \
                    .sum() \
                    .reset_index(drop=False) \
                    .pivot(index="quarter", columns="state", values="trips")

# create the total level df
df_total = df.groupby("quarter")["trips"] \
             .sum() \
             .to_frame() \
             .rename(columns={"trips": "total"})

# join the DataFrames
hierarchy_df = df_bottom_level.join(df_middle_level) \
                              .join(df_total)
hierarchy_df.index = pd.to_datetime(hierarchy_df.index)
hierarchy_df = hierarchy_df.resample("QS") \
                           .sum()

print(f"Number of time series at the bottom level: {df_bottom_level.shape[1]}")
print(f"Number of time series at the middle level: {df_middle_level.shape[1]}")

hierarchy_df.head()
# Out:
# Number of time series at the bottom level: 77
# Number of time series at the middle level: 7
#             ACT_Canberra  NSW_Blue_Mountains  ...           WA         total
# quarter                                       ...
# 1998-01-01    551.001921          195.543180  ...  1641.089495  23932.544141
# 1998-04-01    416.025623          200.408671  ...  1576.326534  20856.726540
# 1998-07-01    436.029011          253.359689  ...  1588.293692  20222.802189
# 1998-10-01    449.798445          245.573846  ...  1839.716990  21342.960517
# 1999-01-01    378.572817          290.484124  ...  1835.687573  22801.711403
#
# [5 rows x 85 columns]

# %%
states = df["state"].unique()
regions = df["state_region"].unique()

total = {'total': list(states)}
state = {k: [v for v in regions if v.startswith(k)] for k in states}
hierarchy = {**total, **state}

#hierarchy

# %%
from hts.hierarchy import HierarchyTree

ht = HierarchyTree.from_nodes(nodes=hierarchy, df=hierarchy_df)
ht
# Out:
# - total
#    |- SA
#    |  |- SA_Adelaide
#    |  |- SA_Adelaide_Hills
#    |  |- SA_Barossa
#    |  |- SA_Clare_Valley
#    |  |- SA_Eyre_Peninsula
#    |  |- SA_Fleurieu_Peninsula
#    |  |- SA_Flinders_Ranges_and_Outback
#    |  |- SA_Kangaroo_Island
#    |  |- SA_Limestone_Coast
#    |  |- SA_Murraylands
#    |  |- SA_Riverland
#    |  - SA_Yorke_Peninsula
#    |- NT
#    |  |- NT_Alice_Springs
#    |  |- NT_Barkly
#    |  |- NT_Darwin
#    |  |- NT_East_Coast
#    |  |- NT_Hobart_and_the_South
#    |  |- NT_Kakadu_Arnhem
#    |  |- NT_Katherine_Daly
#    |  |- NT_Lasseter
#    |  |- NT_Launceston,_Tamar_and_the_North
#    |  |- NT_MacDonnell
#    |  |- NT_North_West
#    |  |- NT_Tasmania
#    |  - NT_Wilderness_West
#    |- WA
#    |  |- WA_Australias_Coral_Coast
#    |  |- WA_Australias_Golden_Outback
#    |  |- WA_Australias_North_West
#    |  |- WA_Australias_South_West
#    |  - WA_Experience_Perth
#    |- VIC
#    |  |- VIC_Ballarat
#    |  |- VIC_Bendigo_Loddon
#    |  |- VIC_Central_Highlands
#    |  |- VIC_Central_Murray
#    |  |- VIC_Geelong
#    |  |- VIC_Gippsland
#    |  |- VIC_Goulburn
#    |  |- VIC_High_Country
#    |  |- VIC_Lakes
#    |  |- VIC_Macedon
#    |  |- VIC_Mallee
#    |  |- VIC_Melbourne
#    |  |- VIC_Melbourne_East
#    |  |- VIC_Murray_East
#    |  |- VIC_Peninsula
#    |  |- VIC_Phillip_Island
#    |  |- VIC_Spa_Country
#    |  |- VIC_Upper_Yarra
#    |  |- VIC_Western
#    |  |- VIC_Western_Grampians
#    |  - VIC_Wimmera
#    |- NSW
#    |  |- NSW_Blue_Mountains
#    |  |- NSW_Capital_Country
#    |  |- NSW_Central_Coast
#    |  |- NSW_Central_NSW
#    |  |- NSW_Hunter
#    |  |- NSW_New_England_North_West
#    |  |- NSW_North_Coast_NSW
#    |  |- NSW_Outback_NSW
#    |  |- NSW_Riverina
#    |  |- NSW_Snowy_Mountains
#    |  |- NSW_South_Coast
#    |  |- NSW_Sydney
#    |  - NSW_The_Murray
#    |- QLD
#    |  |- QLD_Brisbane
#    |  |- QLD_Bundaberg
#    |  |- QLD_Central_Queensland
#    |  |- QLD_Darling_Downs
#    |  |- QLD_Fraser_Coast
#    |  |- QLD_Gold_Coast
#    |  |- QLD_Mackay
#    |  |- QLD_Northern
#    |  |- QLD_Outback
#    |  |- QLD_Sunshine_Coast
#    |  |- QLD_Tropical_North_Queensland
#    |  - QLD_Whitsundays
#    - ACT
#       - ACT_Canberra

# %% [markdown]
# #Visualizing the data

# %%
hierarchy_df["total"].plot(title="Trips - total level");

# %%
ax = hierarchy_df[hierarchy['total']].plot(title="Trips - state level")
ax.legend(bbox_to_anchor=(1.0, 1.0));

# %%
ax = hierarchy_df[hierarchy['WA']].plot(title="Trips - regions of Western Australia")
ax.legend(bbox_to_anchor=(1.0, 1.0));

# %% [markdown]
# #Hierarchical time series forecasting

# %%
def plot_results(pred_df, source_df, cols_to_plot):
    """
    Helper function used for displaying the predictions vs. actuals for the indicated columns
    """
    
    if type(cols_to_plot) == str:
        cols_to_plot = list(cols_to_plot)
        
    for col in cols_to_plot:
        fig, ax = plt.subplots()
        pred_df[col].plot(ax=ax, label="Predicted")
        source_df[col].plot(ax=ax, label="Observed")
        
        ax.legend()
        ax.set_title(col)
        ax.set_xlabel("Date")
        ax.set_ylabel("Trips");

# %% [markdown]
# #  The optimal combination using OLS

# %%
model_ols_prophet = hts.HTSRegressor(model='prophet', revision_method='OLS', n_jobs=0)
model_ols_prophet = model_ols_prophet.fit(hierarchy_df, hierarchy)
pred_ols_prophet = model_ols_prophet.predict(steps_ahead=4)
# Out:
# Fitting models:   0%|          | 0/85 [00:00<?, ?it/s]INFO:numexpr.utils:NumExpr defaulting to 2 threads.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:   1%|          | 1/85 [00:03<05:23,  3.85s/it]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:   2%|▏         | 2/85 [00:04<03:01,  2.18s/it]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:   4%|▎         | 3/85 [00:06<02:20,  1.72s/it]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:   5%|▍         | 4/85 [00:07<01:57,  1.45s/it]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:   6%|▌         | 5/85 [00:07<01:40,  1.25s/it]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:   7%|▋         | 6/85 [00:09<01:34,  1.19s/it]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:   8%|▊         | 7/85 [00:10<01:30,  1.16s/it]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:   9%|▉         | 8/85 [00:10<01:17,  1.01s/it]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  11%|█         | 9/85 [00:11<01:10,  1.08it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  12%|█▏        | 10/85 [00:12<00:58,  1.27it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  13%|█▎        | 11/85 [00:12<00:55,  1.34it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  14%|█▍        | 12/85 [00:13<00:50,  1.44it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  15%|█▌        | 13/85 [00:13<00:47,  1.52it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  16%|█▋        | 14/85 [00:14<00:48,  1.47it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  18%|█▊        | 15/85 [00:15<00:46,  1.51it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  19%|█▉        | 16/85 [00:15<00:44,  1.55it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  20%|██        | 17/85 [00:16<00:46,  1.46it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  21%|██        | 18/85 [00:17<00:47,  1.41it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  22%|██▏       | 19/85 [00:18<00:48,  1.36it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  24%|██▎       | 20/85 [00:18<00:48,  1.34it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  25%|██▍       | 21/85 [00:19<00:44,  1.44it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  26%|██▌       | 22/85 [00:20<00:44,  1.42it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  27%|██▋       | 23/85 [00:20<00:44,  1.38it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  28%|██▊       | 24/85 [00:21<00:42,  1.42it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  29%|██▉       | 25/85 [00:22<00:42,  1.41it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  31%|███       | 26/85 [00:23<00:42,  1.40it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  32%|███▏      | 27/85 [00:23<00:37,  1.54it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  33%|███▎      | 28/85 [00:24<00:38,  1.50it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  34%|███▍      | 29/85 [00:24<00:36,  1.53it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  35%|███▌      | 30/85 [00:25<00:31,  1.72it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  36%|███▋      | 31/85 [00:25<00:31,  1.72it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  38%|███▊      | 32/85 [00:26<00:31,  1.66it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  39%|███▉      | 33/85 [00:27<00:30,  1.71it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  40%|████      | 34/85 [00:28<00:36,  1.41it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  41%|████      | 35/85 [00:28<00:31,  1.61it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  42%|████▏     | 36/85 [00:29<00:37,  1.30it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  44%|████▎     | 37/85 [00:30<00:38,  1.25it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  45%|████▍     | 38/85 [00:31<00:40,  1.16it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  46%|████▌     | 39/85 [00:32<00:38,  1.20it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  47%|████▋     | 40/85 [00:33<00:39,  1.14it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  48%|████▊     | 41/85 [00:33<00:36,  1.22it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  49%|████▉     | 42/85 [00:34<00:37,  1.14it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  51%|█████     | 43/85 [00:35<00:33,  1.26it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  52%|█████▏    | 44/85 [00:36<00:33,  1.23it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  53%|█████▎    | 45/85 [00:37<00:34,  1.17it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  54%|█████▍    | 46/85 [00:37<00:30,  1.29it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  55%|█████▌    | 47/85 [00:38<00:26,  1.45it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  56%|█████▋    | 48/85 [00:39<00:25,  1.46it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  58%|█████▊    | 49/85 [00:39<00:25,  1.43it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  59%|█████▉    | 50/85 [00:40<00:27,  1.26it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  60%|██████    | 51/85 [00:41<00:27,  1.26it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  61%|██████    | 52/85 [00:42<00:31,  1.06it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  62%|██████▏   | 53/85 [00:44<00:31,  1.01it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  64%|██████▎   | 54/85 [00:45<00:30,  1.00it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  65%|██████▍   | 55/85 [00:45<00:27,  1.10it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  66%|██████▌   | 56/85 [00:46<00:24,  1.19it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  67%|██████▋   | 57/85 [00:47<00:25,  1.08it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  68%|██████▊   | 58/85 [00:48<00:24,  1.10it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  69%|██████▉   | 59/85 [00:49<00:22,  1.15it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  71%|███████   | 60/85 [00:49<00:20,  1.22it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  72%|███████▏  | 61/85 [00:50<00:20,  1.20it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  73%|███████▎  | 62/85 [00:51<00:16,  1.41it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  74%|███████▍  | 63/85 [00:52<00:16,  1.32it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  75%|███████▌  | 64/85 [00:52<00:15,  1.35it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  76%|███████▋  | 65/85 [00:53<00:16,  1.18it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  78%|███████▊  | 66/85 [00:54<00:16,  1.14it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  79%|███████▉  | 67/85 [00:55<00:16,  1.11it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  80%|████████  | 68/85 [00:56<00:15,  1.07it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  81%|████████  | 69/85 [00:58<00:16,  1.03s/it]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  82%|████████▏ | 70/85 [00:59<00:15,  1.01s/it]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  84%|████████▎ | 71/85 [00:59<00:12,  1.10it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  85%|████████▍ | 72/85 [01:00<00:11,  1.15it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  86%|████████▌ | 73/85 [01:01<00:10,  1.14it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  87%|████████▋ | 74/85 [01:01<00:08,  1.27it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  88%|████████▊ | 75/85 [01:02<00:07,  1.35it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  89%|████████▉ | 76/85 [01:03<00:07,  1.21it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  91%|█████████ | 77/85 [01:04<00:06,  1.27it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  92%|█████████▏| 78/85 [01:05<00:06,  1.09it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  93%|█████████▎| 79/85 [01:06<00:04,  1.20it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  94%|█████████▍| 80/85 [01:06<00:03,  1.31it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  95%|█████████▌| 81/85 [01:08<00:03,  1.10it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  96%|█████████▋| 82/85 [01:08<00:02,  1.09it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  98%|█████████▊| 83/85 [01:09<00:01,  1.05it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models:  99%|█████████▉| 84/85 [01:11<00:00,  1.03it/s]INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Fitting models: 100%|██████████| 85/85 [01:11<00:00,  1.19it/s]
# Fitting models: 100%|██████████| 85/85 [02:13<00:00,  1.57s/it]
# INFO:hts.core.regressor:Reconciling forecasts using <hts.revision.RevisionMethod object at 0x7f57ae6bdb10>

# %%
from sklearn.metrics import mean_squared_error
import numpy as np

from statsmodels.tools.eval_measures import rmse
arr=np.array(pred_ols_prophet.iloc[0,:])
arr1=np.array(hierarchy_df['total'])
print('RMSE',rmse(arr[:len(arr1)],arr1))

plot_results(pred_ols_prophet, hierarchy_df, cols_to_plot=['total'])
# Out:
# RMSE 21099.472326297706

# %%
plot_results(pred_ols_prophet, hierarchy_df, cols_to_plot=['SA'])
arr=np.array(pred_ols_prophet['SA'])
arr1=np.array(hierarchy_df['SA'])
print('RMSE',rmse(arr[:len(arr1)],arr1))
# Out:
# RMSE 77.32167850569266

# %%
plot_results(pred_ols_prophet, hierarchy_df, cols_to_plot=['SA_Adelaide_Hills'])
arr=np.array(pred_ols_prophet['SA_Adelaide_Hills'])
arr1=np.array(hierarchy_df['SA_Adelaide_Hills'])
print('RMSE',rmse(arr[:len(arr1)],arr1))
# Out:
# RMSE 12.112493727799853
